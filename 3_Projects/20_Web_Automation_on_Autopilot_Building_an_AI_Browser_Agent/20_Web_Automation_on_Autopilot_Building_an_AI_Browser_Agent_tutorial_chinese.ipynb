# %% [markdown]
# # 项目 20：自动驾驶式网页自动化：AI 浏览器 Agent
#
# **项目目标：** 学习 AI 浏览器 Agent 如何自动执行网页任务。
#
# ### 如何使用这份中文教学 notebook
#
# 1. 先阅读概念说明，再运行对应代码。
# 2. 按顺序执行代码单元。
# 3. 每个阶段都观察输出并解释结果。
# 4. 最后根据提交要求完成自己的扩展。

# %% [markdown]
# ### 浏览器自动化配置
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Agent 工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Agent 工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Agent 工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### **Key Capabilities and Use Cases**
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### 浏览器自动化配置
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### 浏览器自动化配置
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### 环境准备与库导入
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Agent 工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Output Format
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### 浏览器自动化配置
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Clone the repository:
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Navigate into the directory:
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### 浏览器自动化配置
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### 浏览器自动化配置
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### 模型构建
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Pipeline 推理任务
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Pipeline 推理任务
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### 浏览器自动化配置
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Access the Services:
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### > Find me the most recent remote data scientist entry levels in India
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Examples
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Basic Search
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### ```python
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Form Filling
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### ```python
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Data Extraction
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### ```python
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### Agent 工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### ```python
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。

# %% [markdown]
# ### 浏览器自动化配置
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：浏览器 Agent、任务执行、LLM 配置、Web UI 和自动化风险。
