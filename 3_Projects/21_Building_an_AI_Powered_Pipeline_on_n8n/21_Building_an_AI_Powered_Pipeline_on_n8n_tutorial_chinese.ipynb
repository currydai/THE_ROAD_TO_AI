# %% [markdown]
# # 项目 21：基于 n8n 的 AI 自动化流水线
#
# **项目目标：** 用 n8n 设计 AI 驱动的自动化流水线。
#
# ### 如何使用这份中文教学 notebook
#
# 1. 先阅读概念说明，再运行对应代码。
# 2. 按顺序执行代码单元。
# 3. 每个阶段都观察输出并解释结果。
# 4. 最后根据提交要求完成自己的扩展。

# %% [markdown]
# ### n8n 自动化工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### n8n 自动化工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### n8n 自动化工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### n8n 自动化工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### n8n 自动化工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### n8n 自动化工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### 探索性数据分析
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### n8n 自动化工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### n8n 自动化工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### 流程图或视觉参考
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### n8n 自动化工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### n8n 自动化工作流
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### Access the editor at `http://localhost:5678`
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。

# %% [markdown]
# ### 流程图或视觉参考
#
# 本节对应原 notebook 中的主题：$f。
#
# 学习时请关注三个问题：这一节解决什么问题，为什么需要这一步，以及后续代码输出如何证明这一步有效。本项目当前学习重点是：工作流自动化、触发器、过滤器、动作节点和本地运行 n8n。
